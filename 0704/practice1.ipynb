# %%
class Person:
    def __init__(self):
        print("初始化：一個新的人被建立了")
p1 = Person()
type(p1)
# Out:
# 初始化：一個新的人被建立了
# __main__.Person

# %%
class Person:
    def __init__(self, name):
        #建立一個attribute
        self.name = name

    def introduce(self):
        print(f"Hi, my name is {self.name}")
p4 = Person("zoey")
p4.introduce()
# Out:
# Hi, my name is zoey

# %%
class Person:
    def __init__(self, name):
        # 建立一個 attribute
        self.name = name

    def introduce(self):
        # 注意：這個方法必須縮排，與 __init__ 對齊，表示它屬於 Person 類別
        print(f"Hi, my name is {self.name}")

# 以下所有的實例化與呼叫，都必須回到最左邊（不縮排），代表在類別外部執行
p2 = Person("robert")
print(p2.name)

p3 = Person("mary")
print(p3.name)

p4 = Person("zoey")
p4.introduce()
# Out:
# robert
# mary
# Hi, my name is zoey

# %%
import yfinance as yf

ticker = "2330.TW"  # 台積電

df = yf.download(
    ticker,
    start="2020-01-01",
    end="2024-12-31",
    interval="1d",
    auto_adjust=False
)

df.tail()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import yfinance as yf
#       3 ticker = "2330.TW"  # 台積電
#       5 df = yf.download(
#       6     ticker,
#       7     start="2020-01-01",
#    (...)
#      10     auto_adjust=False
#      11 )
#
# ModuleNotFoundError: No module named 'yfinance'
